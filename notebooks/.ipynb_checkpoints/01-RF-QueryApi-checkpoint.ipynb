# %%
import requests
import pandas as pd

# %%
df = pd.DataFrame()
df_list = []
for i in range(1,3):
    url = 'https://api.hackathon-03.batch2.lisbondatascience.org/api/data?page_size=5&page='+ str(i)
    payload = {'Authorization': 'token fe0bfd98e3920dd027bd4ca2f796b322e6f95c35'}
    result = requests.get(url,headers=payload).json()
    print(result['results'])
# Out:
# [{'sk_id_curr': 100004, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': 0, 'name_education_type': 'Secondary / secondary special', 'name_income_type': 'Working', 'flag_document_13': False, 'emergencystate_mode': '', 'days_birth': -19046, 'apartments_avg': None, 'flag_document_9': False, 'obs_30_cnt_social_circle': 0}, {'sk_id_curr': 100006, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': None, 'name_education_type': 'Secondary / secondary special', 'name_income_type': 'Working', 'flag_document_13': False, 'emergencystate_mode': '', 'days_birth': -19005, 'apartments_avg': None, 'flag_document_9': False, 'obs_30_cnt_social_circle': 2}, {'sk_id_curr': 100012, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': None, 'name_education_type': 'Secondary / secondary special', 'name_income_type': 'Working', 'flag_document_13': False, 'emergencystate_mode': '', 'days_birth': -14469, 'apartments_avg': None, 'flag_document_9': False, 'obs_30_cnt_social_circle': 2}, {'sk_id_curr': 100014, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': 0, 'name_education_type': 'Higher education', 'name_income_type': 'Working', 'flag_document_13': False, 'emergencystate_mode': '', 'days_birth': -10197, 'apartments_avg': None, 'flag_document_9': False, 'obs_30_cnt_social_circle': 0}, {'sk_id_curr': 100015, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': 0, 'name_education_type': 'Secondary / secondary special', 'name_income_type': 'Pensioner', 'flag_document_13': False, 'emergencystate_mode': '', 'days_birth': -20417, 'apartments_avg': None, 'flag_document_9': False, 'obs_30_cnt_social_circle': 0}, {'sk_id_curr': 100017, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': 0, 'name_education_type': 'Secondary / secondary special', 'name_income_type': 'Working', 'flag_document_13': False, 'emergencystate_mode': 'No', 'days_birth': -14086, 'apartments_avg': '0.14740', 'flag_document_9': False, 'obs_30_cnt_social_circle': 0}, {'sk_id_curr': 100018, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': None, 'name_education_type': 'Secondary / secondary special', 'name_income_type': 'Working', 'flag_document_13': False, 'emergencystate_mode': 'No', 'days_birth': -14583, 'apartments_avg': '0.34950', 'flag_document_9': False, 'obs_30_cnt_social_circle': 0}, {'sk_id_curr': 100019, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': 0, 'name_education_type': 'Secondary / secondary special', 'name_income_type': 'Working', 'flag_document_13': False, 'emergencystate_mode': '', 'days_birth': -8728, 'apartments_avg': None, 'flag_document_9': False, 'obs_30_cnt_social_circle': 0}, {'sk_id_curr': 100030, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': 0, 'name_education_type': 'Secondary / secondary special', 'name_income_type': 'Working', 'flag_document_13': False, 'emergencystate_mode': 'No', 'days_birth': -19334, 'apartments_avg': '0.07220', 'flag_document_9': False, 'obs_30_cnt_social_circle': 0}, {'sk_id_curr': 100032, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': 0, 'name_education_type': 'Secondary / secondary special', 'name_income_type': 'Working', 'flag_document_13': False, 'emergencystate_mode': '', 'days_birth': -15948, 'apartments_avg': None, 'flag_document_9': False, 'obs_30_cnt_social_circle': 2}, {'sk_id_curr': 100034, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': None, 'name_education_type': 'Higher education', 'name_income_type': 'Working', 'flag_document_13': False, 'emergencystate_mode': 'No', 'days_birth': -10341, 'apartments_avg': '0.15050', 'flag_document_9': False, 'obs_30_cnt_social_circle': 0}, {'sk_id_curr': 100035, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': 0, 'name_education_type': 'Secondary / secondary special', 'name_income_type': 'Commercial associate', 'flag_document_13': False, 'emergencystate_mode': 'No', 'days_birth': -15280, 'apartments_avg': '0.01240', 'flag_document_9': False, 'obs_30_cnt_social_circle': 0}, {'sk_id_curr': 100040, 'flag_document_12 ...
# [{'sk_id_curr': 107434, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': 0, 'name_education_type': 'Secondary / secondary special', 'name_income_type': 'Pensioner', 'flag_document_13': False, 'emergencystate_mode': 'No', 'days_birth': -23340, 'apartments_avg': '0.03710', 'flag_document_9': False, 'obs_30_cnt_social_circle': 0}, {'sk_id_curr': 107440, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': None, 'name_education_type': 'Higher education', 'name_income_type': 'Pensioner', 'flag_document_13': False, 'emergencystate_mode': '', 'days_birth': -21098, 'apartments_avg': None, 'flag_document_9': False, 'obs_30_cnt_social_circle': 0}, {'sk_id_curr': 107442, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': 0, 'name_education_type': 'Secondary / secondary special', 'name_income_type': 'Working', 'flag_document_13': False, 'emergencystate_mode': 'No', 'days_birth': -14804, 'apartments_avg': '0.20410', 'flag_document_9': False, 'obs_30_cnt_social_circle': 2}, {'sk_id_curr': 107450, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': 0, 'name_education_type': 'Secondary / secondary special', 'name_income_type': 'State servant', 'flag_document_13': False, 'emergencystate_mode': '', 'days_birth': -9837, 'apartments_avg': None, 'flag_document_9': False, 'obs_30_cnt_social_circle': 1}, {'sk_id_curr': 107451, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': 1, 'name_education_type': 'Secondary / secondary special', 'name_income_type': 'Pensioner', 'flag_document_13': False, 'emergencystate_mode': '', 'days_birth': -21053, 'apartments_avg': None, 'flag_document_9': False, 'obs_30_cnt_social_circle': 2}, {'sk_id_curr': 107452, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': 0, 'name_education_type': 'Secondary / secondary special', 'name_income_type': 'Working', 'flag_document_13': False, 'emergencystate_mode': 'No', 'days_birth': -12656, 'apartments_avg': '0.18450', 'flag_document_9': False, 'obs_30_cnt_social_circle': 0}, {'sk_id_curr': 107457, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': 0, 'name_education_type': 'Secondary / secondary special', 'name_income_type': 'Working', 'flag_document_13': False, 'emergencystate_mode': '', 'days_birth': -21048, 'apartments_avg': None, 'flag_document_9': False, 'obs_30_cnt_social_circle': 2}, {'sk_id_curr': 107461, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': 0, 'name_education_type': 'Secondary / secondary special', 'name_income_type': 'Working', 'flag_document_13': False, 'emergencystate_mode': '', 'days_birth': -14948, 'apartments_avg': None, 'flag_document_9': False, 'obs_30_cnt_social_circle': 0}, {'sk_id_curr': 107462, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': 0, 'name_education_type': 'Lower secondary', 'name_income_type': 'Pensioner', 'flag_document_13': False, 'emergencystate_mode': '', 'days_birth': -20973, 'apartments_avg': None, 'flag_document_9': False, 'obs_30_cnt_social_circle': 16}, {'sk_id_curr': 107466, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': 0, 'name_education_type': 'Secondary / secondary special', 'name_income_type': 'Working', 'flag_document_13': False, 'emergencystate_mode': 'No', 'days_birth': -19499, 'apartments_avg': '0.08250', 'flag_document_9': False, 'obs_30_cnt_social_circle': 0}, {'sk_id_curr': 107468, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': 0, 'name_education_type': 'Secondary / secondary special', 'name_income_type': 'Working', 'flag_document_13': False, 'emergencystate_mode': 'No', 'days_birth': -19767, 'apartments_avg': '0.00000', 'flag_document_9': False, 'obs_30_cnt_social_circle': 0}, {'sk_id_curr': 107473, 'flag_document_12': False, 'amt_req_credit_bureau_qrt': 0, 'name_education_type': 'Higher education', 'name_income_type': 'Commercial associate', 'flag_document_13': True, 'emergencystate_mode': '', 'days_birth': -11571, 'apartments_avg': None, 'flag_document_9': False, 'obs_30_cnt_social_circle': 3}, {'sk_id_curr': 107474, 'flag_document_12': False, ' ...

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-286e2bcbdf72> in <module>()
# ----> 1 df_list[0].head()
#
# IndexError: list index out of range
